# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Housing2.csv")

# %% [markdown]
# ## Understanding Data

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7229300521  20141013T000000  231300.0         2       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.shape
# Out:
# (21613, 21)

# %%
pd.set_option("display.max_columns", None)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521  20141013T000000  231300.0         2       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df = df.astype({"bathrooms": "int",
          "floors":"int"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  int64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  int64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580306e+09  5.400886e+05      3.370795      1.749734   2079.899736
# std    2.876570e+09  3.671268e+05      0.930105      0.734873    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.000000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.000000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.000000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.446213      0.007542      0.234303      3.409430
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only="True")
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001240  -0.000040    -0.012259 -0.132109
# price         -0.016762  1.000000  0.308377   0.510071     0.702035  0.089661
# bedrooms       0.001240  0.308377  1.000000   0.467481     0.576693  0.031713
# bathrooms     -0.000040  0.510071  0.467481   1.000000     0.697875  0.085310
# sqft_living   -0.012259  0.702035  0.576693   0.697875     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031713   0.085310     0.172826  1.000000
# floors         0.019118  0.237210  0.155676   0.484822     0.353321 -0.008951
# waterfront    -0.002721  0.266370 -0.006578   0.058798     0.103818  0.021604
# view           0.011592  0.397294  0.079543   0.177257     0.284611  0.074710
# condition     -0.023784  0.036361  0.028502  -0.126016    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356978   0.606631     0.762704  0.113621
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521  20141013T000000  231300.0         2          1         1180
# 1  6414100192  20141209T000000  538000.0         3          2         2570
# 2  5631500400  20150225T000000  180000.0         2          1          770
# 3  2487200875  20141209T000000  604000.0         4          3         1960
# 4  1954400510  20150218T000000  510000.0         3          2         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650       1           0     0          3      7        1180
# 1      7242       2           0     0          3      7        2170
# 2     10000       1           0     0          3      6         770
# 3      5000       1           0     0          5      7        1050
# 4      8080       1           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
sns.countplot(x='condition', data=df)
# Out:
# <Axes: xlabel='condition', ylabel='count'>

# %%
df["bedrooms"].value_counts()
# Out:
# bedrooms
# 3     9823
# 4     6882
# 2     2761
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
df['bedrooms'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['sqft_living'], bins=8)
# Out:
# (array([1.1111e+04, 9.1640e+03, 1.1740e+03, 1.3300e+02, 2.4000e+01,
#         5.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([  290.  ,  1946.25,  3602.5 ,  5258.75,  6915.  ,  8571.25,
#         10227.5 , 11883.75, 13540.  ]),
#  <BarContainer object of 8 artists>)

# %%
sns.displot(df['sqft_living'])

# %%
sns.boxplot(df['sqft_living'])
# Out:
# <Axes: ylabel='sqft_living'>

# %% [markdown]
# ## Bivariate Analysis

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips, x=tips['total_bill'], y=tips['tip'], hue=tips['sex'], style=tips['time'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips['total_bill'].sum()
# Out:
# np.float64(4827.77)

# %%
tips[tips['sex']=='Male']['tip']
# Out:
# 1      1.66
# 2      3.50
# 3      3.31
# 5      4.71
# 6      2.00
#        ...
# 236    1.00
# 237    1.17
# 239    5.92
# 241    2.00
# 242    1.75
# Name: tip, Length: 157, dtype: float64

# %%
tips[tips['sex']=='Male']['total_bill'].sum()
# Out:
# np.float64(3256.8199999999997)

# %%
group = tips[['sex', 'tip', 'total_bill']].groupby(['sex'], observed=False).sum()

# %%
group
# Out:
#            tip  total_bill
# sex
# Male    485.07     3256.82
# Female  246.51     1570.95

# %%
group['tip_percentage'] = (group['tip']/group['total_bill'])*100

# %%
group
# Out:
#            tip  total_bill  tip_percentage
# sex
# Male    485.07     3256.82       14.893976
# Female  246.51     1570.95       15.691779

# %%
titanic2 = sns.load_dataset('titanic')

# %%
titanic2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
pd.crosstab(titanic2['sex'], titanic2['survived'])
# Out:
# survived    0    1
# sex
# female     81  233
# male      468  109

# %%
titanic2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.boxplot(data=titanic2, x=titanic2['sex'], y=titanic2['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.displot(titanic2[titanic2['survived']==1]['age'])

# %%
sns.heatmap(pd.crosstab(titanic2['sex'], titanic2['survived']))
# Out:
# <Axes: xlabel='survived', ylabel='sex'>

# %%
sns.clustermap(pd.crosstab(titanic2['sex'], titanic2['survived']))

# %%
sns.pairplot(titanic2)

# %%
sns.heatmap(pd.pivot_table(flights, values='passengers', index='month', columns='year', observed=False))
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ydata_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
# !pip install pandas-profiling
# Out:
# Access is denied.
