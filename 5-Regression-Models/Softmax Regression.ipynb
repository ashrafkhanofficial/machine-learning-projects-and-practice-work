# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.drop(columns=['sepal_width','petal_width'],inplace=True)

# %%
encoder = LabelEncoder()

# %%
df['species'] = encoder.fit_transform(df['species'])

# %%
df.sample(5)
# Out:
#     sepal_length  petal_length  species
# 95           5.7           4.2        1
# 87           6.3           4.4        1
# 72           6.3           4.9        1
# 76           6.8           4.8        1
# 32           5.2           1.5        0

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['species']),df['species'],test_size=0.2,
                                                random_state=42)

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
query = np.array([[3.4,2.7]])
clf.predict(query)
# Out:
# C:\Users\Ashrafkhan\anaconda3\envs\datascience\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(df[['sepal_length','petal_length']].values,df['species'].values,clf,legend=2)

plt.xlabel('sepal length')
plt.ylabel('petal lenght')
plt.title('softmax regression')

plt.show()
# Out:
# C:\Users\Ashrafkhan\anaconda3\envs\datascience\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
