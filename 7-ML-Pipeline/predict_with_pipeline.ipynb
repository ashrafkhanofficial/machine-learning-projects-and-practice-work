# %%
import pickle
import numpy as np
import pandas as pd

# %%
pipe = pickle.load(open('models/pipe.pkl','rb'))

# %%
user_input = pd.DataFrame({'pclass':[2], 'sex':['male'], 'age':[22], 'embarked':['S']})

# %%
user_input = np.array([2, 'male', 22, 'S'], dtype=object).reshape(1,4)

# %%
pipe.predict(user_input)
# Out:
# array([0], dtype=int64)
